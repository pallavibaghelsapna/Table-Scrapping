# %%
import pandas as pd

# %%
df = pd.read_csv("table.csv")

# %%
df.head()
# Out:
#    SN            ProjectName          Registration Number Authorised Name  \
# 0   1       SPARSH LIFE CITY  \r\nPCGRERA160218000001\r\n   VIVEK AGRAWAL
# 1   2  OVERSEAS PALM RESORTS  \r\nPCGRERA240218000002\r\n  AAKASH AGRAWAL
# 2   3      MULTI SPORTS CITY  \r\nPCGRERA010318000003\r\n   VIKAS AGRAWAL
# 3   4     MAHAVIR SUNCITY NX  \r\nPCGRERA080318000004\r\n     VIKAS BOHRA
# 4   5     SATGURU DREAM CITY  \r\nPCGRERA150318000005\r\n    SUNNY BINDRA
#
#                               Promoter Name         Project Type     District  \
# 0         MAA BAMLESHWARI REALITIES PVT LTD  Plotted Development       RAIPUR
# 1  M/S AGRAWAL CONSTRUCTION AND CONTRACTORS        Group Housing       RAIPUR
# 2                         BHARAT DEVELOPERS  Plotted Development         DURG
# 3                        MAHAVIR ASSOCIATES  Plotted Development  RAJNANDGAON
# 4                     M/S. SATGURU BUILDCON  Plotted Development       RAIPUR
#
#         Tehsil Approved Date  \
# 0       RAIPUR   16 Feb 2018
# 1       RAIPUR   24 Feb 2018
# 2        PATAN   01 Mar 2018
# 3  RAJNANDGAON   08 Mar 2018
# 4       RAIPUR   15 Mar 2018
#
#                                    Proposed End Date  \
# 0  \r\r\n                                        ...
# 1  \r\r\n                                        ...
# 2  \r\r\n                                        ...
# 3  \r\r\n                                        ...
# 4  \r\r\n                                        ...
#
#   Extended Proposed End Date       Website  View Certificate    Details  \
# 0                30 Jan 2022  \r\n\r\n\r\n  \r\n Expired\r\n  \r\n \r\n
# 1                02 Sep 2022  \r\n\r\n\r\n         \r\n \r\n  \r\n \r\n
# 2                17 Dec 2022  \r\n\r\n\r\n         \r\n \r\n  \r\n \r\n
# 3                08 May 2022  \r\n\r\n\r\n  \r\n Expired\r\n  \r\n \r\n
# 4                          -  \r\n\r\n\r\n  \r\n Expired\r\n  \r\n \r\n
#
#          Map
# 0  \r\n \r\n
# 1  \r\n \r\n
# 2  \r\n \r\n
# 3  \r\n \r\n
# 4  \r\n \r\n

# %%
drop_columns = ["Website",	"View Certificate",	"Details",	"Map"]
df.drop(drop_columns, axis=1, inplace=True)

# %%
df
# Out:
#         SN                                        ProjectName  \
# 0        1                                   SPARSH LIFE CITY
# 1        2                              OVERSEAS PALM RESORTS
# 2        3                                  MULTI SPORTS CITY
# 3        4                                 MAHAVIR SUNCITY NX
# 4        5                                 SATGURU DREAM CITY
# ...    ...                                                ...
# 1466  1467                                           VINYAKAM
# 1467  1468  PMAY AT GEETANJALI CITY COLONY (58DUS) USLAPUR...
# 1468  1469                                      DWARIKA NIWAS
# 1469  1470                  KRISHNA LIFESTYLE COLONY PHASE -2
# 1470  1471                                    GAYATRI ENCLAVE
#
#               Registration Number         Authorised Name  \
# 0     \r\nPCGRERA160218000001\r\n           VIVEK AGRAWAL
# 1     \r\nPCGRERA240218000002\r\n          AAKASH AGRAWAL
# 2     \r\nPCGRERA010318000003\r\n           VIKAS AGRAWAL
# 3     \r\nPCGRERA080318000004\r\n             VIKAS BOHRA
# 4     \r\nPCGRERA150318000005\r\n            SUNNY BINDRA
# ...                           ...                     ...
# 1466  \r\nPCGRERA010722001462\r\n           NITESH SHARMA
# 1467  \r\nPCGRERA010722001463\r\n  PANKAJ KUMAR PANCHAITY
# 1468  \r\nPCGRERA010722001464\r\n     DWARIKA PALLAV SAHU
# 1469  \r\nPCGRERA010722001465\r\n     SUNIL KUMAR TAPARIA
# 1470  \r\nPCGRERA050722001466\r\n      RAGHVENDRA  GUPTA
#
#                                   Promoter Name  \
# 0             MAA BAMLESHWARI REALITIES PVT LTD
# 1      M/S AGRAWAL CONSTRUCTION AND CONTRACTORS
# 2                             BHARAT DEVELOPERS
# 3                            MAHAVIR ASSOCIATES
# 4                         M/S. SATGURU BUILDCON
# ...                                         ...
# 1466                             S.S.ASSOCIATES
# 1467  E.E.MUNICIPAL CORPORATION BILASPUR (C.G.)
# 1468                       MAA KARMA PROPERTIES
# 1469                   SHREE KRISHNA DEVELOPERS
# 1470                    GAYATRI  CONSTRUCTIONS
#
#                          Project Type     District       Tehsil Approved Date  \
# 0                 Plotted Development       RAIPUR       RAIPUR   16 Feb 2018
# 1                       Group Housing       RAIPUR       RAIPUR   24 Feb 2018
# 2                 Plotted Development         DURG        PATAN   01 Mar 2018
# 3                 Plotted Development  RAJNANDGAON  RAJNANDGAON   08 Mar 2018
# 4                 Plotted Development       RAIPUR       RAIPUR   15 Mar 2018
# ...                               ...          ...          ...           ...
# 1466  Residential Plotted Development  BALODABAZAR  BALODABAZAR   01 Jul 2022
# 1467                    Group Housing     BILASPUR     BILASPUR   01 Jul 2022
# 1468  Residential Plotted Development         DURG         DURG   01 Jul 2022
# 1469                    Group Housing       RAIPUR        TILDA   01 Jul 2022
# 1470  Residential Plotted Development     BILASPUR     BILASPUR   05 Jul 2022
#
#                                       Proposed End Date  \
# 0     \r\r\n                                        ...
# 1     \r\r\n                                        ...
# 2     \r\r\n                                        ...
# 3     \r\r\n                                        ...
# 4     \r\r\n                                        ...
# ...                                                 ...
# 1466  \r\r\n                                        ...
# 1467  \r\r\n                                        ...
# 1468  \r\r\n                                        ...
# 1469  \r\r\n                                        ...
# 1470  \r\r\n                                        ...
#
#      Extended Proposed End Date
# 0                   30 Jan 2022
# 1                   02 Sep 2022
# 2                   17 Dec 2022
# 3                   08 May 2022
# 4                             -
# ...                         ...
# 1466                          -
# 1467                          -
# 1468                          -
# 1469                          -
# 1470                          -
#
# [1471 rows x 11 columns]

# %%
df.to_csv("table_modified.csv")
